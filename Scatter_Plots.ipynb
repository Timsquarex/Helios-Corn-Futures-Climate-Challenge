# %% [markdown]
# ## Scatter Plots for Different Climate Features with Different Futures Features

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data/featured_dataset_1.csv')
data.head()
# Out:
#                                      ID                crop_name country_name  \
# 0  34d5ae60-e671-45c3-af60-078b5386d6a9  Corn: Commodity Tracked       Russia
# 1  b2220150-05a9-4158-9f9d-9c02913c8742  Corn: Commodity Tracked       Russia
# 2  eedcf99b-5c5f-4761-ac5f-1d5c375a7974  Corn: Commodity Tracked       Russia
# 3  0a048187-abee-4aeb-bba7-480764ace9f8  Corn: Commodity Tracked       Russia
# 4  5cb7c33e-b97e-4681-89f2-db58dd22a0f5  Corn: Commodity Tracked       Russia
#
#   country_code           region_name                             region_id  \
# 0           RU  Republic of Mordovia  01ab8962-db3d-49ef-af56-b877ce4f59d7
# 1           RU  Republic of Mordovia  01ab8962-db3d-49ef-af56-b877ce4f59d7
# 2           RU  Republic of Mordovia  01ab8962-db3d-49ef-af56-b877ce4f59d7
# 3           RU  Republic of Mordovia  01ab8962-db3d-49ef-af56-b877ce4f59d7
# 4           RU  Republic of Mordovia  01ab8962-db3d-49ef-af56-b877ce4f59d7
#
# ...

# %%
print(len(data['country_name'].unique()))

climate_features = [c for c in data.columns if c.startswith('climate_risk')]
futures_features = [c for c in data.columns if c.startswith('futures_')]

climate_features
# Out:
# 11
# ['climate_risk_cnt_locations_heat_stress_risk_low',
#  'climate_risk_cnt_locations_heat_stress_risk_medium',
#  'climate_risk_cnt_locations_heat_stress_risk_high',
#  'climate_risk_cnt_locations_unseasonably_cold_risk_low',
#  'climate_risk_cnt_locations_unseasonably_cold_risk_medium',
#  'climate_risk_cnt_locations_unseasonably_cold_risk_high',
#  'climate_risk_cnt_locations_excess_precip_risk_low',
#  'climate_risk_cnt_locations_excess_precip_risk_medium',
#  'climate_risk_cnt_locations_excess_precip_risk_high',
#  'climate_risk_cnt_locations_drought_risk_low',
#  'climate_risk_cnt_locations_drought_risk_medium',
#  'climate_risk_cnt_locations_drought_risk_high',
#  'climate_risk_cnt_locations_wildfires_risk_medium',
#  'climate_risk_cnt_locations_wildfires_risk_high',
#  'climate_risk_cnt_locations_storms_risk_medium',
#  'climate_risk_cnt_locations_storms_risk_high',
#  'climate_risk_cnt_locations_heatwave_risk_high',
#  'climate_risk_cnt_locations_heatwave_risk_medium',
# ...
